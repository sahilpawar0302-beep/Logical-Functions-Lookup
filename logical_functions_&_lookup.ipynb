# %% [markdown]
# 1.write a formula to check if the marks in cell are greater than or equal to 40. If yes, return , otherwise "fail"
#
#   - Check if marks in B2 ≥ 40:
#   =IF(B2>=40,"Pass","Fail")
#
#
# 2.company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not
#
#   - Condition: Sales > 40000 AND Attendance ≥ 90%
#   - IF(AND(B2>40000,C2>=90),"Bonus","No Bonus")
#
# 3.rite a nested IF formula:
# If marks in are ≥ 90 → , ≥ 75 → , ≥ 50 → , otherwise . B2 "A" "B" "C" "Fail" .
#
#  -Condition:
#
# ≥ 90 → A
# ≥ 75 → B
# ≥ 50 → C
# Otherwise → Fail .
#
#  -=IF(B2>=90,"A",IF(B2>=75,"B",IF(B2>=50,"C","Fail")))
#
# 4.Find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?.
#
#  - From the table:
# E103 → Roshni → Finance
#
# Which LOOKUP function & why?
#
# Use VLOOKUP because:
#
# Data is arranged vertically
# EmpID is in the first column
#
#  - =VLOOKUP("E103",A2:C5,3,FALSE)
#
# 5.A company has set the following commission structure for its sales team:
#
#   -Commission table:
#
# 0 → 5%
#
# 20000 → 10%
#
# 50000 → 15%
#
# 80000 → 20%
#
# ₹45,000 falls between 20,000 and 50,000 → 10%
#
# Formula:
#
# =VLOOKUP(45000,A2:B5,2,TRUE)
#
#
# 6.The HR department maintains the following leave records of employees:onus or not .
#
#  - Condition: Leaves Taken > Allowed Leaves
#
# =IF(B2>C2,"Exceeded","OK")
#
#
# 7.Find the salary of EmpID = E105 using INDEX-MATCH Function.
#
#   -Formula:
#
# =INDEX(B2:B6,MATCH("E105",A2:A6,0))
#
# This returns the salary corresponding to E105.
#
# 8.U se the XLOOKUP function to find the Department of the employee with Emp ID = E303.
#
#   -From table:
# E303 → IT
#
# Formula:
#
# =XLOOKUP("E303",A2:A5,B2:B5)
